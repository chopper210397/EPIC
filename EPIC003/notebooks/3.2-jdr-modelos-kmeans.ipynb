# %% [markdown]
# # Kmeans Modelos Seleccionados

# %% [markdown]
# ## 1. Importar librerías

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
from sklearn.cluster import KMeans
from random import sample
from sklearn.ensemble import IsolationForest
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
import shap

#Mostrar todas las columnas de un dataframe
pd.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ## 2. Importación de data

# %%
#Seleccionar ruta de la data
dataframe = pd.read_csv(r'C:\GIT_Cumplimiento\epic\EPIC003\data\modeling\03_train.csv', encoding='latin')
dataframe.shape
# Out:
# (37639, 13)

# %% [markdown]
# ## 3. Modelo

# %%
#REviso columnas
dataframe.columns
# Out:
# Index(['Unnamed: 0', 'PERIODO', 'CODCLAVECIC', 'NBRCLIORDENANTE', 'SEGMENTO',
#        'MTO_TRANSF', 'CTD_OPE', 'FLG_PEP', 'FLG_PROF', 'FLG_PAR', 'FLG_PERFIL',
#        'CTDEVAL', 'FLG_PAIS'],
#       dtype='object')

# %% [markdown]
# ### Model 1: Variables modelo estándar (Todas las variables)

# %%
#Selecciono variables
ds1=dataframe[['MTO_TRANSF', 'CTD_OPE', 'FLG_PEP', 'FLG_PROF', 'FLG_PERFIL','CTDEVAL', 'FLG_PAIS']]
#Estandarizo variables
data1_cluster = MinMaxScaler().fit_transform(ds1)

#Calculo silueta final  k=13
ki=13
outputKMeans = KMeans(n_clusters = ki, init='k-means++', random_state = 7).fit(data1_cluster)
scoreSilhoutte = metrics.silhouette_score(data1_cluster, outputKMeans.labels_, metric='euclidean')
print(" k=", ki," SC=", scoreSilhoutte)
# Out:
#  k= 13  SC= 0.9763299901994965

# %%
#Entreno modelo
clustering1=KMeans(n_clusters=13,init='k-means++', random_state = 7)
clustering1.fit(data1_cluster)
#Asigno etiquetas de cluster como variable
dataframe1=dataframe.copy()
dataframe1['N_Cluster']=clustering1.labels_
#Valido creación de variable con clusters
dataframe1.head(5)
# Out:
#    Unnamed: 0  PERIODO  CODCLAVECIC                 NBRCLIORDENANTE  \
# 0           0   202206          812   CORTES DE POLAR SANDRA MIRIAN
# 1           1   202204          898  FORNO CASTRO-POZO XENNIA MARIA
# 2           2   202207          961    INOPE MANTERO CARLOS ALBERTO
# 3           3   202209          961    INOPE MANTERO CARLOS ALBERTO
# 4           6   202209         1604       MARIN ALCALDE WILDER JUAN
#
#     SEGMENTO  MTO_TRANSF  CTD_OPE  FLG_PEP  FLG_PROF  FLG_PAR  FLG_PERFIL  \
# 0     ENALTA   100000.00        1        0         1        2           0
# 1     ENALTA     5416.06        1        0         0        0           0
# 2     ENALTA     1218.52        1        0         0        0           0
# 3     ENALTA     3703.35        1        0         0        2           0
# 4  EXCLUSIVO     2906.34        1        0         0        2           0
#
#    CTDEVAL  FLG_PAIS  N_Cluster
# 0        0         1          3
# 1        0         0          1
# 2        1         0          1
# 3        1         1          2
# 4        0         1          2

# %%
#Valido número de casos por cluster
dataframe1.groupby('N_Cluster').N_Cluster.count()
# Out:
# N_Cluster
# 0      4299
# 1     14255
# 2      8927
# 3      7681
# 4       872
# 5       454
# 6       405
# 7       282
# 8       187
# 9       156
# 10       41
# 11       44
# 12       36
# Name: N_Cluster, dtype: int64

# %%
dataframe2.groupby('N_Cluster').N_Cluster.count().to_clipboard()

# %%
#Perfilamiento media por variable por cluster
dataframe1.groupby('N_Cluster').mean().round(3)
# Out:
#            Unnamed: 0     PERIODO   CODCLAVECIC  MTO_TRANSF  CTD_OPE  FLG_PEP  \
# N_Cluster
# 0           27729.258  202206.628  8.255207e+06   30342.686    1.383      0.0
# 1           24549.366  202206.562  6.649207e+06   24650.373    1.350      0.0
# 2           26186.814  202206.585  7.144770e+06   29643.758    1.309      0.0
# 3           32746.495  202206.613  1.043268e+07   24233.416    1.322      0.0
# 4           23673.383  202206.586  6.361951e+06  108206.659    2.073      0.0
# 5           25952.370  202206.542  7.061603e+06   70331.459    2.115      0.0
# 6           33022.262  202206.454  1.045617e+07   31428.259    2.047      0.0
# 7           12899.149  202206.762  1.848288e+06   19289.151    1.273      1.0
# 8           24393.385  202206.487  6.880010e+06   53095.626    2.150      0.0
# 9           17945.090  202206.410  3.176164e+06   27845.520    1.276      1.0
# 10          10676.073  202206.927  1.317768e+06  354106.563    2.098      1.0
# 11          19774.273  202206.273  4.115425e+06   11576.891    1.205      1.0
# 12          12602.056  202206.139  1.695392e+06  125481.446    2.083      1.0
#
#            FLG_PROF  FLG_PAR  FLG_PERFIL  CTDEVAL  FLG_PAIS
# N_Cluster
# 0               1.0    0.000       0.000    0.512      0.00
# 1               0.0    0.000       0.000    0.796      0.00
# 2               0.0    1.916       0.000    0.349      1.00
# 3               1.0    1.956       0.000    0.148      1.00
# 4               0.0    0.000       1.000    1.272      0.00
# 5               0.0    1.850       1.000    0.648      1.00
# 6               1.0    1.936       1.000    0.180      1.00
# 7               0.0    0.000       0.000    5.468      0.00
# 8               1.0    0.000       1.000    0.711      0.00
# 9               0.0    1.936       0.000    1.096      1.00
# 10              1.0    0.000       0.000    3.927      0.00
# 11              1.0    1.909       0.091    1.636      1.00
# 12              0.0    0.472       1.000    7.167      0.25

# %%
#Perfilamiento desviacióne estándar por variable por cluster
dataframe1.groupby('N_Cluster').std().round(3)
# Out:
#            Unnamed: 0  PERIODO  CODCLAVECIC   MTO_TRANSF  CTD_OPE  FLG_PEP  \
# N_Cluster
# 0           15932.179    1.721  8410698.410   494173.346    0.893      0.0
# 1           15693.392    1.722  7408430.564   190008.526    0.922      0.0
# 2           15193.957    1.717  7354833.419    92479.763    0.907      0.0
# 3           14704.753    1.718  8505252.579    94318.559    0.819      0.0
# 4           15812.143    1.685  7424540.302   597037.022    1.470      0.0
# 5           15189.822    1.746  7344182.052   232593.415    1.502      0.0
# 6           14444.039    1.705  8285163.436    61950.642    1.889      0.0
# 7            9788.752    1.711  2456990.336    54352.240    0.590      0.0
# 8           16313.550    1.711  8071709.977   205642.104    1.502      0.0
# 9           11365.453    1.741  3628067.349    67745.929    0.741      0.0
# 10           8872.591    1.780  1818053.834  2066817.270    2.200      0.0
# 11          14018.843    1.717  4293272.736    19349.501    0.462      0.0
# 12           9606.719    1.659  1742805.966   339304.104    1.645      0.0
#
#            FLG_PROF  FLG_PAR  FLG_PERFIL  CTDEVAL  FLG_PAIS
# N_Cluster
# 0               0.0    0.000       0.000    2.609     0.000
# 1               0.0    0.000       0.000    2.891     0.000
# 2               0.0    0.277       0.000    1.815     0.000
# 3               0.0    0.205       0.000    0.993     0.000
# 4               0.0    0.000       0.000    4.052     0.000
# 5               0.0    0.357       0.000    2.566     0.000
# 6               0.0    0.245       0.000    1.024     0.000
# 7               0.0    0.000       0.000   20.206     0.000
# 8               0.0    0.000       0.000    2.376     0.000
# 9               0.0    0.246       0.000    2.896     0.000
# 10              0.0    0.000       0.000    6.861     0.000
# 11              0.0    0.291       0.291    5.981     0.000
# 12              0.0    0.845       0.000   27.110     0.439

# %%
#Exporto tabla con variable del modelo a excel
dataframe1.to_excel(r'C:\GIT_Cumplimiento\epic\EPIC003\reports\others\KM1_13seg.xlsx',index=False,header=True)

# %% [markdown]
# ### Model 2: Variables modelo estándar sin variable CTDEVAL

# %%
#Selecciono variables
ds2=dataframe[['MTO_TRANSF', 'CTD_OPE', 'FLG_PEP', 'FLG_PROF', 'FLG_PERFIL','FLG_PAIS']]
#Estandarizo variables
data2_cluster = MinMaxScaler().fit_transform(ds2)
#Selecciono cluster silueta final
ki = 14
#Calculo silueta
outputKMeans = KMeans(n_clusters = ki, init='k-means++', random_state = 7).fit(data2_cluster)
scoreSilhoutte = metrics.silhouette_score(data2_cluster, outputKMeans.labels_, metric='euclidean')
print(" k=", ki," SC=", scoreSilhoutte)
# Out:
#  k= 14  SC= 0.9812538774004375

# %%
#Entreno modelo
clustering2=KMeans(n_clusters=14,init='k-means++', random_state = 7)
clustering2.fit(data2_cluster)
#Asigno etiquetas de cluster como variable
dataframe2=dataframe.copy()
dataframe2['N_Cluster']=clustering2.labels_
#Valido creación de variable con clusters
dataframe2.head(5)
# Out:
#    Unnamed: 0  PERIODO  CODCLAVECIC                 NBRCLIORDENANTE  \
# 0           0   202206          812   CORTES DE POLAR SANDRA MIRIAN
# 1           1   202204          898  FORNO CASTRO-POZO XENNIA MARIA
# 2           2   202207          961    INOPE MANTERO CARLOS ALBERTO
# 3           3   202209          961    INOPE MANTERO CARLOS ALBERTO
# 4           6   202209         1604       MARIN ALCALDE WILDER JUAN
#
#     SEGMENTO  MTO_TRANSF  CTD_OPE  FLG_PEP  FLG_PROF  FLG_PAR  FLG_PERFIL  \
# 0     ENALTA   100000.00        1        0         1        2           0
# 1     ENALTA     5416.06        1        0         0        0           0
# 2     ENALTA     1218.52        1        0         0        0           0
# 3     ENALTA     3703.35        1        0         0        2           0
# 4  EXCLUSIVO     2906.34        1        0         0        2           0
#
#    CTDEVAL  FLG_PAIS  N_Cluster
# 0        0         1          1
# 1        0         0          2
# 2        1         0          2
# 3        1         1          0
# 4        0         1          0

# %%
#Valido número de casos por cluster
dataframe2.groupby('N_Cluster').N_Cluster.count()
# Out:
# N_Cluster
# 0      8927
# 1      7681
# 2     14255
# 3      4299
# 4       282
# 5       872
# 6       454
# 7       405
# 8       187
# 9       156
# 10       41
# 11       40
# 12       27
# 13       13
# Name: N_Cluster, dtype: int64

# %%
#Perfilamiento media por variable por cluster
dataframe2.groupby('N_Cluster').mean().round(3)
# Out:
#            Unnamed: 0     PERIODO   CODCLAVECIC  MTO_TRANSF  CTD_OPE  FLG_PEP  \
# N_Cluster
# 0           26186.814  202206.585  7.144770e+06   29643.758    1.309      0.0
# 1           32746.495  202206.613  1.043268e+07   24233.416    1.322      0.0
# 2           24549.366  202206.562  6.649207e+06   24650.373    1.350      0.0
# 3           27729.258  202206.628  8.255207e+06   30342.686    1.383      0.0
# 4           12899.149  202206.762  1.848288e+06   19289.151    1.273      1.0
# 5           23673.383  202206.586  6.361951e+06  108206.659    2.073      0.0
# 6           25952.370  202206.542  7.061603e+06   70331.459    2.115      0.0
# 7           33022.262  202206.454  1.045617e+07   31428.259    2.047      0.0
# 8           24393.385  202206.487  6.880010e+06   53095.626    2.150      0.0
# 9           17945.090  202206.410  3.176164e+06   27845.520    1.276      1.0
# 10          10676.073  202206.927  1.317768e+06  354106.563    2.098      1.0
# 11          19299.800  202206.325  3.993510e+06   11823.776    1.175      1.0
# 12          11735.704  202206.185  1.609666e+06  102232.317    1.889      1.0
# 13          18068.154  202205.923  2.993185e+06  137960.900    2.308      1.0
#
#            FLG_PROF  FLG_PAR  FLG_PERFIL  CTDEVAL  FLG_PAIS
# N_Cluster
# 0             0.000    1.916         0.0    0.349       1.0
# 1             1.000    1.956         0.0    0.148       1.0
# 2             0.000    0.000         0.0    0.796       0.0
# 3             1.000    0.000         0.0    0.512       0.0
# 4             0.000    0.000         0.0    5.468       0.0
# 5             0.000    0.000         1.0    1.272       0.0
# 6             0.000    1.850         1.0    0.648       1.0
# 7             1.000    1.936         1.0    0.180       1.0
# 8             1.000    0.000         1.0    0.711       0.0
# 9             0.000    1.936         0.0    1.096       1.0
# 10            1.000    0.000         0.0    3.927       0.0
# 11            1.000    1.900         0.0    1.775       1.0
# 12            0.000    0.000         1.0    9.222       0.0
# 13            0.308    1.923         1.0    0.769       1.0

# %%
#Perfilamiento desviacióne estándar por variable por cluster
dataframe2.groupby('N_Cluster').std().round(3)
# Out:
#            Unnamed: 0  PERIODO  CODCLAVECIC   MTO_TRANSF  CTD_OPE  FLG_PEP  \
# N_Cluster
# 0           15193.957    1.717  7354833.419    92479.763    0.907      0.0
# 1           14704.753    1.718  8505252.579    94318.559    0.819      0.0
# 2           15693.392    1.722  7408430.564   190008.526    0.922      0.0
# 3           15932.179    1.721  8410698.410   494173.346    0.893      0.0
# 4            9788.752    1.711  2456990.336    54352.240    0.590      0.0
# 5           15812.143    1.685  7424540.302   597037.022    1.470      0.0
# 6           15189.822    1.746  7344182.052   232593.415    1.502      0.0
# 7           14444.039    1.705  8285163.436    61950.642    1.889      0.0
# 8           16313.550    1.711  8071709.977   205642.104    1.502      0.0
# 9           11365.453    1.741  3628067.349    67745.929    0.741      0.0
# 10           8872.591    1.780  1818053.834  2066817.270    2.200      0.0
# 11          13955.674    1.760  4378817.550    20135.894    0.446      0.0
# 12          10305.632    1.665  1922220.925   296016.699    1.396      0.0
# 13          10739.750    1.553  2571917.061   386112.440    1.932      0.0
#
#            FLG_PROF  FLG_PAR  FLG_PERFIL  CTDEVAL  FLG_PAIS
# N_Cluster
# 0              0.00    0.277         0.0    1.815       0.0
# 1              0.00    0.205         0.0    0.993       0.0
# 2              0.00    0.000         0.0    2.891       0.0
# 3              0.00    0.000         0.0    2.609       0.0
# 4              0.00    0.000         0.0   20.206       0.0
# 5              0.00    0.000         0.0    4.052       0.0
# 6              0.00    0.357         0.0    2.566       0.0
# 7              0.00    0.245         0.0    1.024       0.0
# 8              0.00    0.000         0.0    2.376       0.0
# 9              0.00    0.246         0.0    2.896       0.0
# 10             0.00    0.000         0.0    6.861       0.0
# 11             0.00    0.304         0.0    6.261       0.0
# 12             0.00    0.000         0.0   31.158       0.0
# 13             0.48    0.277         0.0    1.536       0.0

# %%
#Exporto tabla con variable del modelo a excel
dataframe2.to_excel(r'C:\GIT_Cumplimiento\epic\EPIC003\reports\others\KM2_13seg.xlsx',index=False,header=True)

# %% [markdown]
# ### Model 3: Variables modelo estándar sin variables CTDOPE

# %%
#Selecciono variables
ds3=dataframe[['MTO_TRANSF', 'CTDEVAL', 'FLG_PEP', 'FLG_PROF', 'FLG_PERFIL','FLG_PAIS']]
#Estandarizo variables
data3_cluster = MinMaxScaler().fit_transform(ds3)
#Selecciono números de clusters silueta final
k = 14
#Calculo silueta
outputKMeans = KMeans(n_clusters = ki, init='k-means++', random_state = 7).fit(data3_cluster)
scoreSilhoutte = metrics.silhouette_score(data3_cluster, outputKMeans.labels_, metric='euclidean')
print(" k=", ki," SC=", scoreSilhoutte)
# Out:
#  k= 13  SC= 0.991795090764557

# %%
#Entreno modelo
clustering3=KMeans(n_clusters=14,init='k-means++', random_state = 7)
clustering3.fit(data3_cluster)
#Asigno etiquetas de cluster como variable
dataframe3=dataframe.copy()
dataframe3['N_Cluster']=clustering3.labels_
#Valido creación de variable con clusters
dataframe3.head(5)
# Out:
#    Unnamed: 0  PERIODO  CODCLAVECIC                 NBRCLIORDENANTE  \
# 0           0   202206          812   CORTES DE POLAR SANDRA MIRIAN
# 1           1   202204          898  FORNO CASTRO-POZO XENNIA MARIA
# 2           2   202207          961    INOPE MANTERO CARLOS ALBERTO
# 3           3   202209          961    INOPE MANTERO CARLOS ALBERTO
# 4           6   202209         1604       MARIN ALCALDE WILDER JUAN
#
#     SEGMENTO  MTO_TRANSF  CTD_OPE  FLG_PEP  FLG_PROF  FLG_PAR  FLG_PERFIL  \
# 0     ENALTA   100000.00        1        0         1        2           0
# 1     ENALTA     5416.06        1        0         0        0           0
# 2     ENALTA     1218.52        1        0         0        0           0
# 3     ENALTA     3703.35        1        0         0        2           0
# 4  EXCLUSIVO     2906.34        1        0         0        2           0
#
#    CTDEVAL  FLG_PAIS  N_Cluster
# 0        0         1          2
# 1        0         0          1
# 2        1         0          1
# 3        1         1          0
# 4        0         1          0

# %%
#Valido número de casos por cluster
dataframe3.groupby('N_Cluster').N_Cluster.count()
# Out:
# N_Cluster
# 0      8927
# 1     14255
# 2      7681
# 3      4299
# 4       872
# 5       454
# 6       405
# 7       282
# 8       187
# 9       156
# 10       41
# 11       40
# 12       27
# 13       13
# Name: N_Cluster, dtype: int64

# %%
#Perfilamiento media por variable por cluster
dataframe3.groupby('N_Cluster').mean().round(3)
# Out:
#            Unnamed: 0     PERIODO   CODCLAVECIC  MTO_TRANSF  CTD_OPE  FLG_PEP  \
# N_Cluster
# 0           26186.814  202206.585  7.144770e+06   29643.758    1.309      0.0
# 1           24549.366  202206.562  6.649207e+06   24650.373    1.350      0.0
# 2           32746.495  202206.613  1.043268e+07   24233.416    1.322      0.0
# 3           27729.258  202206.628  8.255207e+06   30342.686    1.383      0.0
# 4           23673.383  202206.586  6.361951e+06  108206.659    2.073      0.0
# 5           25952.370  202206.542  7.061603e+06   70331.459    2.115      0.0
# 6           33022.262  202206.454  1.045617e+07   31428.259    2.047      0.0
# 7           12899.149  202206.762  1.848288e+06   19289.151    1.273      1.0
# 8           24393.385  202206.487  6.880010e+06   53095.626    2.150      0.0
# 9           17945.090  202206.410  3.176164e+06   27845.520    1.276      1.0
# 10          10676.073  202206.927  1.317768e+06  354106.563    2.098      1.0
# 11          19299.800  202206.325  3.993510e+06   11823.776    1.175      1.0
# 12          11735.704  202206.185  1.609666e+06  102232.317    1.889      1.0
# 13          18068.154  202205.923  2.993185e+06  137960.900    2.308      1.0
#
#            FLG_PROF  FLG_PAR  FLG_PERFIL  CTDEVAL  FLG_PAIS
# N_Cluster
# 0             0.000    1.916         0.0    0.349       1.0
# 1             0.000    0.000         0.0    0.796       0.0
# 2             1.000    1.956         0.0    0.148       1.0
# 3             1.000    0.000         0.0    0.512       0.0
# 4             0.000    0.000         1.0    1.272       0.0
# 5             0.000    1.850         1.0    0.648       1.0
# 6             1.000    1.936         1.0    0.180       1.0
# 7             0.000    0.000         0.0    5.468       0.0
# 8             1.000    0.000         1.0    0.711       0.0
# 9             0.000    1.936         0.0    1.096       1.0
# 10            1.000    0.000         0.0    3.927       0.0
# 11            1.000    1.900         0.0    1.775       1.0
# 12            0.000    0.000         1.0    9.222       0.0
# 13            0.308    1.923         1.0    0.769       1.0

# %%
#Perfilamiento desviacióne estándar por variable por cluster
dataframe3.groupby('N_Cluster').std().round(3)
# Out:
#            Unnamed: 0  PERIODO  CODCLAVECIC   MTO_TRANSF  CTD_OPE  FLG_PEP  \
# N_Cluster
# 0           15193.957    1.717  7354833.419    92479.763    0.907      0.0
# 1           15693.392    1.722  7408430.564   190008.526    0.922      0.0
# 2           14704.753    1.718  8505252.579    94318.559    0.819      0.0
# 3           15932.179    1.721  8410698.410   494173.346    0.893      0.0
# 4           15812.143    1.685  7424540.302   597037.022    1.470      0.0
# 5           15189.822    1.746  7344182.052   232593.415    1.502      0.0
# 6           14444.039    1.705  8285163.436    61950.642    1.889      0.0
# 7            9788.752    1.711  2456990.336    54352.240    0.590      0.0
# 8           16313.550    1.711  8071709.977   205642.104    1.502      0.0
# 9           11365.453    1.741  3628067.349    67745.929    0.741      0.0
# 10           8872.591    1.780  1818053.834  2066817.270    2.200      0.0
# 11          13955.674    1.760  4378817.550    20135.894    0.446      0.0
# 12          10305.632    1.665  1922220.925   296016.699    1.396      0.0
# 13          10739.750    1.553  2571917.061   386112.440    1.932      0.0
#
#            FLG_PROF  FLG_PAR  FLG_PERFIL  CTDEVAL  FLG_PAIS
# N_Cluster
# 0              0.00    0.277         0.0    1.815       0.0
# 1              0.00    0.000         0.0    2.891       0.0
# 2              0.00    0.205         0.0    0.993       0.0
# 3              0.00    0.000         0.0    2.609       0.0
# 4              0.00    0.000         0.0    4.052       0.0
# 5              0.00    0.357         0.0    2.566       0.0
# 6              0.00    0.245         0.0    1.024       0.0
# 7              0.00    0.000         0.0   20.206       0.0
# 8              0.00    0.000         0.0    2.376       0.0
# 9              0.00    0.246         0.0    2.896       0.0
# 10             0.00    0.000         0.0    6.861       0.0
# 11             0.00    0.304         0.0    6.261       0.0
# 12             0.00    0.000         0.0   31.158       0.0
# 13             0.48    0.277         0.0    1.536       0.0

# %%
#Exporto tabla con variable del modelo a excel
dataframe3.to_excel(r'C:\GIT_Cumplimiento\epic\EPIC003\reports\others\KM3_13seg.xlsx',index=False,header=True)
