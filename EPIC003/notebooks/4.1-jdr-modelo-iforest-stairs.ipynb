# %% [markdown]
# ## Modelos IForest Seleccionado

# %% [markdown]
# ## 1. Importación de librerías

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
from sklearn.cluster import KMeans
from random import sample
from sklearn.ensemble import IsolationForest
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
import shap

#Mostrar todas las columnas de un dataframe
pd.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ## 2. Importación data

# %%
#Seleccionar ruta de la data
dataframe = pd.read_csv(r'C:\GIT_Cumplimiento\epic\EPIC003\data\modeling\03_train_v4.csv', encoding='latin')
dataframe.shape
# Out:
# (13516, 13)

# %% [markdown]
# ## 3. Universo de riesgo

# %%
#Importo modelo kmeans final
import pickle 
loaded_KM = pickle.load(open(r'KMeans1_9seg_stairs.model', "rb"))

# %%
#Selecciono solo las variables que necesita el modelo
dataset=dataframe[['MTO_TRANSF', 'CTD_OPE', 'FLG_PEP', 'FLG_PROF', 'FLG_PERFIL','CTDEVAL', 'FLG_PAIS']]

#Estandarizo variables
dataset_cluster = MinMaxScaler().fit_transform(dataset)

# %%
#Aplico el modelo cargado sobre la data. Columna Outlier es la que tiene el resultado del modelo
dataframe['N_CLUSTER']=loaded_KM.predict(dataset_cluster)
dataframe.head()
# Out:
#    Unnamed: 0  PERIODO  CODCLAVECIC                 NBRCLIORDENANTE SEGMENTO  \
# 0           0   202206          812   CORTES DE POLAR SANDRA MIRIAN   ENALTA
# 1           8   202209         1750  CONROY DE MARSANO MARIA TERESA  PRIVADA
# 2           9   202204         1973  APARCANA HERRERA MARIELA VILMA  CONSUMO
# 3          12   202204         2249            DANERI PREIS GUSTAVO   ENALTA
# 4          14   202208         2374      FIEDLER VASQUEZ-MEJIA PAUL   ENALTA
#
#    MTO_TRANSF  CTD_OPE  FLG_PEP  FLG_PROF  FLG_PAR  FLG_PERFIL  CTDEVAL  \
# 0   100000.00        1        0         1        2           0        0
# 1    17357.00        1        0         0        0           0       15
# 2    13931.65        1        0         1        0           0        0
# 3    13275.00        1        0         1        0           0        5
# 4    10670.96        2        0         1        0           0        0
#
#    FLG_PAIS  N_CLUSTER
# 0         1          1
# 1         0          2
# 2         0          3
# 3         0          3
# 4         0          3

# %%
#Defino Universo basado en clusters de riesgo seleccionados
dataseg=dataframe[dataframe['N_CLUSTER'].isin([4,5,6,7,8])]
dataseg.shape
# Out:
# (1217, 14)

# %%
#Visualizo dataset
dataseg.head()
# Out:
#     Unnamed: 0  PERIODO  CODCLAVECIC                     NBRCLIORDENANTE  \
# 8           39   202206         4319        SORIA SUAREZ ALCIDES WILLIAM
# 14          62   202209         6083          CALMET PAPANICOLAU GONZALO
# 15          64   202205         6420  ARAUJO ZAPATA MILAGRITOS FRANCISCA
# 30         115   202208         9940      LEGUIA OREZZOLI JOAQUIN FELIPE
# 51         184   202204        12810           RUBIN DE-COL JOSE ANTONIO
#
#      SEGMENTO  MTO_TRANSF  CTD_OPE  FLG_PEP  FLG_PROF  FLG_PAR  FLG_PERFIL  \
# 8      ENALTA   100000.00        1        0         0        0           1
# 14     ENALTA   102653.00        3        0         1        0           1
# 15  EXCLUSIVO    20000.00        1        1         0        0           0
# 30     ENALTA    42096.52        3        0         0        0           1
# 51     ENALTA    30000.00        1        0         1        0           1
#
#     CTDEVAL  FLG_PAIS  N_CLUSTER
# 8         0         0          4
# 14        1         0          6
# 15        0         0          8
# 30        1         0          4
# 51        0         0          6

# %% [markdown]
# ## 3. Modelamiento

# %%
#Reviso columnas
dataseg.columns
# Out:
# Index(['Unnamed: 0', 'PERIODO', 'CODCLAVECIC', 'NBRCLIORDENANTE', 'SEGMENTO',
#        'MTO_TRANSF', 'CTD_OPE', 'FLG_PEP', 'FLG_PROF', 'FLG_PAR', 'FLG_PERFIL',
#        'CTDEVAL', 'FLG_PAIS', 'N_CLUSTER'],
#       dtype='object')

# %%
#Variables
ds1=dataseg[['MTO_TRANSF', 'CTD_OPE', 'FLG_PEP', 'FLG_PROF', 'FLG_PERFIL','CTDEVAL', 'FLG_PAIS']]

#Modelo base IF
iforest1 = IsolationForest(n_estimators = 500, contamination=0.1,random_state=7)
iforest1.fit(ds1)

#score de silueta
datasetv1 = dataseg.copy()
datasetv1['IF_LABEL']=iforest1.predict(ds1)
scoreSilhoutte = metrics.silhouette_score(ds1, datasetv1['IF_LABEL'], metric='euclidean') 
print('Silueta:',scoreSilhoutte)

#Casos estimados
datasetv1.groupby(['PERIODO','IF_LABEL']).size()
# Out:
# Silueta: 0.5258252251435743
# PERIODO  IF_LABEL
# 202204   -1           25
#           1          166
# 202205   -1           21
#           1          198
# 202206   -1           16
#           1          182
# 202207   -1           16
#           1          155
# 202208   -1           21
#           1          208
# 202209   -1           23
#           1          186
# dtype: int64

# %%
datasetv1.groupby(['PERIODO','IF_LABEL']).size().to_clipboard()

# %%
#Reviso el total de outliers
datasetv1.groupby(['IF_LABEL']).size()
# Out:
# IF_LABEL
# -1     122
#  1    1095
# dtype: int64

# %%
#Copio a excel tabla de medias por grupo
datasetv1.groupby('IF_LABEL').mean().round(3).to_clipboard(excel=True)
#Tabla de medias por grupo
datasetv1.groupby('IF_LABEL').mean().round(3)
# Out:
#           Unnamed: 0     PERIODO  CODCLAVECIC  MTO_TRANSF  CTD_OPE  FLG_PEP  \
# IF_LABEL
# -1         13780.975  202206.459  2547391.713  142254.452    3.115    0.582
#  1         25686.273  202206.547  7070712.661   48591.456    2.232    0.067
#
#           FLG_PROF  FLG_PAR  FLG_PERFIL  CTDEVAL  FLG_PAIS  N_CLUSTER
# IF_LABEL
# -1           0.189    0.844       0.492    13.09     0.492      6.631
#  1           0.278    0.893       0.939     0.70     0.471      5.252

# %%
#Exporto a excel tabla scoreada
datasetv1.to_excel(r'C:\GIT_Cumplimiento\epic\EPIC003\reports\others\IForest_resultados_vf.xlsx',index=False,header=True)

# %%
#Guardar el modelo

import pickle
pickle.dump(iforest1, open('IF_EPIC003_alerta.model', 'wb'))

# %% [markdown]
# ## 4. Test sobre mes de prueba

# %%
#Seleccionar ruta de la data
df_test = pd.read_csv(r'C:\GIT_Cumplimiento\epic\EPIC003\data\modeling\04_test.csv', encoding='latin')
df_test.shape
# Out:
# (6148, 13)

# %%
df_test.describe()
# Out:
#          Unnamed: 0   PERIODO   CODCLAVECIC    MTO_TRANSF      CTD_OPE  \
# count   6148.000000    6148.0  6.148000e+03  6.148000e+03  6148.000000
# mean   27242.907775  202210.0  7.863548e+06  2.294791e+04     1.371991
# std    15721.590187       0.0  7.992482e+06  1.478452e+05     0.904794
# min        4.000000  202210.0  1.006000e+03  1.000360e+03     1.000000
# 25%    13720.000000  202210.0  1.651027e+06  2.863932e+03     1.000000
# 50%    27261.500000  202210.0  4.882740e+06  6.379360e+03     1.000000
# 75%    40878.750000  202210.0  1.206654e+07  1.500000e+04     1.000000
# max    54557.000000  202210.0  2.806231e+07  9.300000e+06    21.000000
#
#            FLG_PEP     FLG_PROF      FLG_PAR   FLG_PERFIL      CTDEVAL  \
# count  6148.000000  6148.000000  6148.000000  6148.000000  6148.000000
# mean      0.015777     0.354099     0.912980     0.040501     0.521958
# std       0.124624     0.478278     0.980901     0.197147     2.583880
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     1.000000     2.000000     0.000000     0.000000
# max       1.000000     1.000000     2.000000     1.000000    94.000000
#
#           FLG_PAIS
# count  6148.000000
# mean      0.471698
# std       0.499239
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
datatest=df_test.loc[(df_test['PERIODO']==202210) & (df_test['MTO_TRANSF']>10000) & (df_test['MTO_TRANSF']<500000)]
datatest.shape
# Out:
# (2021, 13)

# %%
#Selecciono solo las variables que necesita el modelo
dstest=datatest[['MTO_TRANSF', 'CTD_OPE', 'FLG_PEP', 'FLG_PROF', 'FLG_PERFIL','CTDEVAL', 'FLG_PAIS']]

#Estandarizo variables
datatest_cluster = MinMaxScaler().fit_transform(dstest)

#Aplico el modelo cargado sobre la data. Columna Outlier es la que tiene el resultado del modelo
datatest['N_CLUSTER']=loaded_KM.predict(datatest_cluster)
datatest.head()
# Out:
#     Unnamed: 0  PERIODO  CODCLAVECIC                    NBRCLIORDENANTE  \
# 0            4   202210         1006        STOCKHOLM BARRIOS CHRISTIAN
# 5           55   202210         5879             MARSANO CONROY CLAUDIA
# 9          108   202210         9133           VIVAS INGA SONIA ROSARIO
# 14         132   202210        10636  DE-LA-PUENTE PARDO CARLOS ANTONIO
# 19         171   202210        12500      ARENAS MEZA MARIA DEL ROSARIO
#
#    SEGMENTO  MTO_TRANSF  CTD_OPE  FLG_PEP  FLG_PROF  FLG_PAR  FLG_PERFIL  \
# 0    ENALTA    100000.0        1        0         0        0           0
# 5   PRIVADA     17948.0        1        0         0        0           0
# 9    ENALTA     12000.0        1        0         0        0           0
# 14   ENALTA     20000.0        1        0         1        2           0
# 19  PRIVADA    150000.0        1        0         1        0           0
#
#     CTDEVAL  FLG_PAIS  N_CLUSTER
# 0         2         0          2
# 5         8         0          2
# 9         3         0          2
# 14        0         1          1
# 19        0         0          3

# %%
#Validoexistencia de clusters de riesgo
datatest['N_CLUSTER'].value_counts()
# Out:
# 2    616
# 0    543
# 1    507
# 3    190
# 4     56
# 5     40
# 7     31
# 8     21
# 6     17
# Name: N_CLUSTER, dtype: int64

# %%
#Defino Universo basado en clusters de riesgo seleccionados
datarisk=datatest[datatest['N_CLUSTER'].isin([4,5,6,7,8])]
datarisk.shape
# Out:
# (165, 14)

# %%
#Aplico IF sobre datarisk
loaded_IF = pickle.load(open(r'IF_EPIC003_alerta.model', "rb"))

dsrisk=datarisk[['MTO_TRANSF', 'CTD_OPE', 'FLG_PEP', 'FLG_PROF', 'FLG_PERFIL','CTDEVAL', 'FLG_PAIS']]

# %%
#Aplico el modelo cargado sobre la data. Columna Outlier es la que tiene el resultado del modelo

datarisk['OUTLIER']=loaded_IF.predict(dsrisk)

datarisk.head()
# Out:
#      Unnamed: 0  PERIODO  CODCLAVECIC                NBRCLIORDENANTE  \
# 33          277   202210        21350           FLORES DIAZ AYDA LUZ
# 54          438   202210        33547          VASQUEZ VELA ANDERSON
# 75          637   202210        44432  WATSON BARBER CHARLES PHILLIP
# 82          700   202210        45857  MERINO CABALLERO ALFREDO ABEL
# 102         894   202210        51733     BANDA PRADO VIDAL RAYMUNDO
#
#          SEGMENTO  MTO_TRANSF  CTD_OPE  FLG_PEP  FLG_PROF  FLG_PAR  \
# 33   PEQ. EMPRESA    13308.94        1        0         1        2
# 54         ENALTA    17434.23        3        0         1        1
# 75   PEQ. EMPRESA    10725.30        1        0         1        2
# 82         ENALTA    32000.00        1        0         0        0
# 102  PEQ. EMPRESA    19651.35        1        1         0        2
#
#      FLG_PERFIL  CTDEVAL  FLG_PAIS  N_CLUSTER  OUTLIER
# 33            1        0         1          7        1
# 54            1        0         1          7        1
# 75            1        0         1          7        1
# 82            1        6         0          4        1
# 102           0        0         1          8        1

# %%
datarisk['OUTLIER'].value_counts()
# Out:
#  1    151
# -1     14
# Name: OUTLIER, dtype: int64

# %%
datarisk.to_excel("ALERTAS_IF.xlsx")
